# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_data=pd.read_csv(r"C:\Users\Administrator\Desktop\Data\housing_data.csv")
housing_data
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL         65.0     8450   Pave   NaN
# 1              1       SC20       RL         80.0     9600   Pave   NaN
# 2              2       SC60       RL         68.0    11250   Pave   NaN
# 3              3       SC70       RL         60.0     9550   Pave   NaN
# 4              4       SC60       RL         84.0    14260   Pave   NaN
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL         62.0     7917   Pave   NaN
# 1456        1456       SC20       RL         85.0    13175   Pave   NaN
# 1457        1457       SC70       RL         66.0     9042   Pave   NaN
# 1458        1458       SC20       RL         68.0     9717   Pave   NaN
# 1459        1459       SC20       RL         75.0     9937   Pave   NaN
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
housing_data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
housing_data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %% [markdown]
# #### 1.Is there any missing values?

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
housing_data['Alley'].unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
housing_data['Alley'].mode()
# Out:
# 0    Grvl
# Name: Alley, dtype: object

# %%
housing_data.fillna('Grv1',inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7464\2636695204.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Grv1' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   housing_data.fillna('Grv1',inplace=True)

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# #### Univariate Analysis
# *Univariate analysis is simplest form of analysis.
# *Only one variable is used in visualisation analysis.This does not deal with relationship plots.
# *It takes data, summarize the data, pattern analysis, trend analysis in data.
# *Univariate analysis can be implemented on **numerical data** or **categorical data**

# %%
df_numerical=housing_data.select_dtypes(include=['number'])
df_numerical
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0            65.0     8450            7            5       2003          2003
# 1            80.0     9600            6            8       1976          1976
# 2            68.0    11250            7            5       2001          2002
# 3            60.0     9550            7            5       1915          1970
# 4            84.0    14260            8            5       2000          2000
# ...           ...      ...          ...          ...        ...           ...
# 1455         62.0     7917            6            5       1999          2000
# 1456         85.0    13175            6            6       1978          1988
# 1457         66.0     9042            7            9       1941          2006
# 1458         68.0     9717            5            6       1950          1996
# 1459         75.0     9937            5            6       1965          1965
#
# ...

# %%
df_categorical=housing_data.select_dtypes(include=['object'])
df_categorical
# Out:
#      MSSubClass MSZoning Street Alley LotShape LandContour Utilities  \
# 0          SC60       RL   Pave  Grv1      Reg         Lvl    AllPub
# 1          SC20       RL   Pave  Grv1      Reg         Lvl    AllPub
# 2          SC60       RL   Pave  Grv1      IR1         Lvl    AllPub
# 3          SC70       RL   Pave  Grv1      IR1         Lvl    AllPub
# 4          SC60       RL   Pave  Grv1      IR1         Lvl    AllPub
# ...         ...      ...    ...   ...      ...         ...       ...
# 1455       SC60       RL   Pave  Grv1      Reg         Lvl    AllPub
# 1456       SC20       RL   Pave  Grv1      Reg         Lvl    AllPub
# 1457       SC70       RL   Pave  Grv1      Reg         Lvl    AllPub
# 1458       SC20       RL   Pave  Grv1      Reg         Lvl    AllPub
# 1459       SC20       RL   Pave  Grv1      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageFinish GarageQual GarageCond  \
# ...

# %% [markdown]
# #### 1.Line Plot
# *Univariate data-Trends Analysis
# *Bivariate data-Relationship Plot

# %%
#Plot using dataframe and plottype
df_numerical['SalePrice'].plot() #kind parameter can be set to different types of plots like piechart,area,line,bar etc
#it is inbuilt function to pandas to create plot
# Out:
# <Axes: >

# %%
sorted_data=df_numerical['SalePrice'].sort_values(ascending=True).unique()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,8))
plt.plot(sorted_data,color='orangered')
plt.xlabel('Index')
plt.ylabel('Price')
#size= set the front size for Title and Labels
plt.title('Trends of Sale Price', size=20)
plt.show()

# %% [markdown]
# #### Bar Plot
# *Univariate or Bivariate Plots
# *Bar chart are used with categorical dataset
# *Bar plots are used to display counts of unique value for categorical type, height of bar indicate count for each categorical

# %%
df_categorical['SaleType'].value_counts()
# Out:
# SaleType
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: count, dtype: int64

# %%
print(df_categorical['SaleType'].value_counts().values)
print(df_categorical['SaleType'].value_counts().index)
# Out:
# [1267  122   43    9    5    5    4    3    2]
# Index(['WD', 'New', 'COD', 'ConLD', 'ConLI', 'ConLw', 'CWD', 'Oth', 'Con'], dtype='object', name='SaleType')

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10,8))
plt.bar(df_categorical['SaleType'].value_counts().index,color='orangered',height=df_categorical['SaleType'].value_counts().values)
plt.xlabel('SaleType')
plt.ylabel('Count')
#size= set the front size for Title and Labels
plt.title('Trends of Sale Type', size=20)
plt.show()

# %%
df_categorical['SaleType'].value_counts().plot(kind='bar',figsize=(11,7),ylabel='Count')
# Out:
# <Axes: xlabel='SaleType', ylabel='Count'>

# %% [markdown]
# #### Histogram
# *Univariate Analysis- Apply on continuos Data
# *Frequency of data in range.
# *Study of Spread/ data distribution

# %%
#bins= 20, Indicates 20 equal distribution of Numerical Data
sns.set_style('whitegrid')
plt.hist(df_numerical['SalePrice'],bins=20)
plt.ylabel('Count')
plt.xlabel('Price')
#size= set the front size for Title and Labels
plt.title('Sale Price Histogram', size=20)
plt.show()

# %%
df_numerical['SalePrice'].plot(kind='hist',bins=20,xlabel="Sale Price",ylabel='Count',title="Price Histogram",color='Blue')
# Out:
# <Axes: title={'center': 'Price Histogram'}, xlabel='Sale Price', ylabel='Count'>

# %% [markdown]
# #### Subplots
# *Here one plot will be splitted into multiple plots. Each index position will be occupied by one Plot

# %%
plt.subplot(1,2,1)
# Out:
# <Axes: >

# %%
df_categorical
# Out:
#      MSSubClass MSZoning Street Alley LotShape LandContour Utilities  \
# 0          SC60       RL   Pave  Grv1      Reg         Lvl    AllPub
# 1          SC20       RL   Pave  Grv1      Reg         Lvl    AllPub
# 2          SC60       RL   Pave  Grv1      IR1         Lvl    AllPub
# 3          SC70       RL   Pave  Grv1      IR1         Lvl    AllPub
# 4          SC60       RL   Pave  Grv1      IR1         Lvl    AllPub
# ...         ...      ...    ...   ...      ...         ...       ...
# 1455       SC60       RL   Pave  Grv1      Reg         Lvl    AllPub
# 1456       SC20       RL   Pave  Grv1      Reg         Lvl    AllPub
# 1457       SC70       RL   Pave  Grv1      Reg         Lvl    AllPub
# 1458       SC20       RL   Pave  Grv1      Reg         Lvl    AllPub
# 1459       SC20       RL   Pave  Grv1      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageFinish GarageQual GarageCond  \
# ...

# %%
df_categorical['LandSlope'].value_counts()
# Out:
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64

# %%
housing_data[housing_data['LandSlope']=='Gtl'].SalePrice
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1382, dtype: int64

# %%
plt.figure(figsize=(11,7))
plt.subplot(2,2,1)
plt.hist(housing_data[housing_data['LandSlope']=='Gtl'].SalePrice,bins=20,color='b',alpha=0.5) #used for varying the transparency
plt.subplot(2,2,2)
plt.hist(housing_data[housing_data['LandSlope']=='Mod'].SalePrice,bins=20,color='g',alpha=0.5)
plt.subplot(2,2,3)
plt.hist(housing_data[housing_data['LandSlope']=='Sev'].SalePrice,bins=20,color='r',alpha=0.5)
plt.show()

# %% [markdown]
# #### Scatter Plot
# *Indicates relationship Plot or Correlation between two numerical columns

# %%
df_numerical
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0            65.0     8450            7            5       2003          2003
# 1            80.0     9600            6            8       1976          1976
# 2            68.0    11250            7            5       2001          2002
# 3            60.0     9550            7            5       1915          1970
# 4            84.0    14260            8            5       2000          2000
# ...           ...      ...          ...          ...        ...           ...
# 1455         62.0     7917            6            5       1999          2000
# 1456         85.0    13175            6            6       1978          1988
# 1457         66.0     9042            7            9       1941          2006
# 1458         68.0     9717            5            6       1950          1996
# 1459         75.0     9937            5            6       1965          1965
#
# ...

# %%
#Considering points with lotarea<60000 as data is concentrated in that region
plt.scatter(df_numerical[df_numerical['LotArea']<60000]['LotArea'], 
            df_numerical[df_numerical['LotArea']<60000]['SalePrice'])

plt.xlabel("LotArea")
plt.ylabel("SalePrice")
plt.title("Relationship b/w LotArea And SalePrice")
# Out:
# Text(0.5, 1.0, 'Relationship b/w LotArea And SalePrice')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=df_numerical[df_numerical['LotArea']<60000]['LotArea'], 
            y=df_numerical[df_numerical['LotArea']<60000]['SalePrice'],hue=df_categorical['HouseStyle'],s=200)
plt.show() #Compulsory for the plot to appear for anywhere other than jupyter notebook

# %%
plt.figure(figsize=(10,8))

#s=size of bubble, marker='s','^','>','<','*','.','+','d','o'
sns.scatterplot(x=df_numerical['GarageArea'], 
            y=df_numerical['SalePrice'],hue=df_categorical['HouseStyle'],s=200,alpha=0.5,marker='*')
plt.show() #Compulsory for the plot to appear for anywhere other than jupyter notebook

# %% [markdown]
# #### Pie-Chart
# *Distribution Plot.

# %%
df_categorical['LotConfig'].value_counts()
# Out:
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.pie(df_categorical['LotConfig'].value_counts(),autopct='%0.2f%%',labels=['Inside','Corner','CulDSac','FR2','FR3'])
plt.legend(loc=1)
plt.show()

# %% [markdown]
# #### Kernel Density Estimator (KDE)
# *Shows Histogram+Density Plot to display distribution of numerical continuous data

# %%
import warnings
warnings.filterwarnings('ignore')  #To remove the warnings
sns.distplot(df_numerical[df_numerical['GarageArea']>0]['GarageArea'],color='blue')
# Out:
# <Axes: xlabel='GarageArea', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df_numerical[df_numerical['GarageArea']>0]['GarageArea'],color='blue',hist=False) #hist=False to disable histogram
# Out:
# <Axes: xlabel='GarageArea', ylabel='Density'>

# %% [markdown]
# #### Box Plot
# *min=q1-1.5IQR
# *max=q3+1.5IQR
#
# Skewness:
# a)

# %%
sns.boxplot(df_numerical[df_numerical['GarageArea']>0]['GarageArea'],orient='h')
# Out:
# <Axes: xlabel='GarageArea'>

# %%
sns.boxplot(x='LotConfig',y='SalePrice',data=housing_data,hue='LotConfig',palette='magma')
# Out:
# <Axes: xlabel='LotConfig', ylabel='SalePrice'>

# %% [markdown]
# #### Violin Plot

# %%
sns.violinplot(df_numerical[df_numerical['GarageArea']>0]['GarageArea'])
# Out:
# <Axes: ylabel='GarageArea'>

# %%
sns.violinplot(x='LotConfig',y='SalePrice',data=housing_data,hue='LotConfig',palette='magma')
# Out:
# <Axes: xlabel='LotConfig', ylabel='SalePrice'>

# %% [markdown]
# #### Heatmap- Multivariate Plot

# %%
df_numerical.corr()
# Out:
#                LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# LotFrontage       1.000000  0.100739     0.176561    -0.053457   0.036853
# LotArea           0.100739  1.000000     0.105806    -0.005636   0.014228
# OverallQual       0.176561  0.105806     1.000000    -0.091932   0.572323
# OverallCond      -0.053457 -0.005636    -0.091932     1.000000  -0.375983
# YearBuilt         0.036853  0.014228     0.572323    -0.375983   1.000000
# YearRemodAdd      0.078686  0.013788     0.550684     0.073741   0.592855
# MasVnrArea        0.105010  0.103321     0.407252    -0.125694   0.311600
# BsmtFinSF1        0.076670  0.214103     0.239666    -0.046231   0.249503
# BsmtFinSF2       -0.009312  0.111170    -0.059119     0.040229  -0.049107
# BsmtUnfSF         0.160829 -0.002618     0.308159    -0.136841   0.149040
# TotalBsmtSF       0.238274  0.260833     0.537808    -0.171098   0.391452
# 1stFlrSF          0.245181  0.299475     0.476224    -0.144203   0.281986
# ...

# %%
df_numerical.corr()[['SalePrice']]
# Out:
#                SalePrice
# LotFrontage     0.209624
# LotArea         0.263843
# OverallQual     0.790982
# OverallCond    -0.077856
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# MasVnrArea      0.472614
# BsmtFinSF1      0.386420
# BsmtFinSF2     -0.011378
# BsmtUnfSF       0.214479
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# 2ndFlrSF        0.319334
# LowQualFinSF   -0.025606
# GrLivArea       0.708624
# BsmtFullBath    0.227122
# BsmtHalfBath   -0.016844
# FullBath        0.560664
# HalfBath        0.284108
# BedroomAbvGr    0.168213
# KitchenAbvGr   -0.135907
# TotRmsAbvGrd    0.533723
# Fireplaces      0.466929
# GarageCars      0.640409
# GarageArea      0.623431
# WoodDeckSF      0.324413
# OpenPorchSF     0.315856
# EnclosedPorch  -0.128578
# 3SsnPorch       0.044584
# ScreenPorch     0.111447
# PoolArea        0.092404
# MiscVal        -0.021190
# YrSold         -0.028923
# SalePrice       1.000000

# %%
plt.figure(figsize=(3,10))
sns.heatmap(df_numerical.corr()[['SalePrice']],annot=True)
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df_numerical.corr(),annot=True)
plt.show()

# %% [markdown]
# #### Area Plot

# %%
housing_data[['SalePrice','LotArea']].plot(kind='area',stacked=True,alpha=0.8) #stacked=True when more thn one value considered
# Out:
# <Axes: >
